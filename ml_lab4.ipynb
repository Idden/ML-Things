# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# Q1
print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
# Q2
x_val = x_train[int(0.8*x_train.shape[0]):, :]
x_train = x_train[:int(0.8*x_train.shape[0]), :]

y_val = y_train[int(0.8*y_train.shape[0]):]
y_train = y_train[:int(0.8*y_train.shape[0])]

# %%
# Q3
model = tf.keras.models.Sequential([
    tf.keras.Input(shape=(28, 28)), # I changed this because I got warning but this basically just creates a layer that vectorizes the 28x28 input.
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'), # If negative activation = 0 if positive activation stays the same. Create 128 neurons for this layer.
    tf.keras.layers.Dropout(0.2), # Randomly turn 20% of neurons to 0 to prevent overfitting.
    tf.keras.layers.Dense(10) # 10 neurons for the digits 0-9
])

# %%
# Q4
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
# ...

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model.compile(optimizer='adam', loss=loss_fn, metrics=['accuracy'])
model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=5)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9037 - loss: 0.3301 - val_accuracy: 0.9542 - val_loss: 0.1597
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9536 - loss: 0.1565 - val_accuracy: 0.9666 - val_loss: 0.1141
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9650 - loss: 0.1173 - val_accuracy: 0.9703 - val_loss: 0.1000
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9721 - loss: 0.0934 - val_accuracy: 0.9733 - val_loss: 0.0875
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9755 - loss: 0.0788 - val_accuracy: 0.9743 - val_loss: 0.0842

# %%
# Q5
model.evaluate(x_test, y_test, verbose=2)
# Out:
# 313/313 - 0s - 1ms/step - accuracy: 0.9759 - loss: 0.0788
# [0.0788072869181633, 0.9758999943733215]

# %%
# Q6
model2 = tf.keras.models.Sequential([
    tf.keras.Input(shape=(28, 28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(200, activation='relu'),
    tf.keras.layers.Dense(200, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

# %%
# Q7
loss_fn2 = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model2.compile(optimizer='adam', loss=loss_fn2, metrics=['accuracy'])
model2.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=5)

model.evaluate(x_test, y_test, verbose=2)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9253 - loss: 0.2505 - val_accuracy: 0.9654 - val_loss: 0.1176
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9690 - loss: 0.1016 - val_accuracy: 0.9718 - val_loss: 0.0976
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9775 - loss: 0.0712 - val_accuracy: 0.9707 - val_loss: 0.0912
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9837 - loss: 0.0518 - val_accuracy: 0.9710 - val_loss: 0.1041
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9864 - loss: 0.0429 - val_accuracy: 0.9703 - val_loss: 0.1087
# 313/313 - 0s - 711us/step - accuracy: 0.9759 - loss: 0.0788
# [0.0788072869181633, 0.9758999943733215]
